# %% [markdown]
# <a href="https://colab.research.google.com/github/elsie-karwitha/This-is-my-first-repository/blob/main/Python_lab_excercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0

# %%
number = 45   # you can also use 7

if number % 2 == 0:
    print(number, "is Even")
else:
    print(number, "is Odd")
# Out:
# 45 is Odd

# %%
a = 10
y = 20

print(a > y)
print(a < y)
# Out:
# False
# True

# %%
num = 45

if num > 0 and num < 100:
    print("The number is positive and less than 100")
else:
    print("The number does not meet the condition")
# Out:
# The number is positive and less than 100

# %%
fruits = ["banana", "orange", "apple", "mango"]

if "apple" in fruits:
    print("Apple is in the list")
else:
    print("Apple is not in the list")
# Out:
# Apple is in the list

# %%
list1 = [1, 2, 3]
list2 = [1, 2, 3]

print(list1 == list2)   # Checks values (True)
print(list1 is list2)   # Checks memory location (False)
# Out:
# True
# False
